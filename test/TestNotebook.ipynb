# %%
from refine import *

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path_a = "../output/6awr_chainA_prep.pdb"
path_b = "../output/6awr_chainB_prep.pdb"
path = "../data/6awr_edited.pdb"
# path = "../data/6awr.pdb"

# %%
# protein = pdy.parsePDB(path)
chain_a = pdy.parsePDB(path_a)
chain_b = pdy.parsePDB(path_b)
protein = pdy.parsePDB(path)
# Out:
# @> 2359 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 2381 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 2818 atoms and 1 coordinate set(s) were parsed in 0.03s.

# %%
full = chain_a + chain_b
pdy.writePDB("../output/tmp_system.pdb", protein)
# Out:
# '../output/tmp_system.pdb'

# %%
pdy.showProtein(protein.select("chain A"), A='blue')
pdy.showProtein(protein.select("chain B"), B='red')
pylab.show()

# %%
force_field = "amber14/protein.ff14SB.xml"
create_system(path, forcefield_name=force_field)
# "../output/tmp_system.pdb"
t0 = time.time()
drs = DRSystem("../output/tmp_system.pdb", forcefield_name=force_field)
print("construction of system:", -t0 + time.time(), "sec")
t0 = time.time()
nmw = NMSpaceWrapper(drs, n_modes=5)
print("construction of NM wrapper:", -t0 + time.time(), "sec")
# Out:
# @> 2818 atoms and 1 coordinate set(s) were parsed in 0.06s.
# write PDB(prody): 0.0217 sec
# read PDB(openmm): 0.16745305061340332 sec
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9a21c6c49d5a> in <module>
#       1 force_field = "amber14/protein.ff14SB.xml"
# ----> 2 create_system(path, forcefield_name=force_field)
#       3 # "../output/tmp_system.pdb"
#       4 t0 = time.time()
#       5 drs = DRSystem("../output/tmp_system.pdb", forcefield_name=force_field)
#
# ~/PycharmProjects/DiplomaPython/source/refine.py in create_system(path, tmp_file, forcefield_name)
#      57     forcefield = app.ForceField(forcefield_name)
#      58     modeller = app.Modeller(omm_object.getTopology(), omm_object.getPositions())
# ---> 59     modeller.addHydrogens(forcefield=forcefield)
#      60     # modeller.addExtraParticles(forcefield=forcefield)
#      61     print("add hydrogens and extra particles(openmm):", time.time() - time0, "sec")
#
# ~/mipt/GPCR-TEAM/env/lib/python3.6/site-packages/simtk/openmm/app/modeller.py in addHydrogens(self, forcefield, pH, variants, platform)
#     845             # Use the ForceField the user specified.
#     846
# --> 847             system = forcefield.createSystem(newTopology, rigidWater=False, nonbondedMethod=CutoffNonPeriodic)
#     848             atoms = list(newTopology.atoms())
#     849             for i in range(system.getNumParticles()):
#
# ~/mipt/GPCR-TEAM/env/lib/python3.6/site-packages/simtk/openmm/app/forcefield.py in createSystem(self, topology, nonbondedMethod, nonbondedCutoff, constraints, rigidWater, removeCMMotion, hydrogenMass, residueTemplates, ignoreExternalBonds, switchDistance, flexibleConstraints, **args)
#    1137                             break
#    1138             if matches is None:
# -> 1139                 raise ValueError('No template found for residue %d (%s).  %s' % (res.index+1, res.name, _findMatchErrors(self, res)))
#    1140             else:
#    1141                 data.recordMatchedAtomParameters(res, template, matches)
#
# ValueError: No template found for residue 260 (GLU).  The set of atoms is similar to ASN, but it is missing 2 atoms.

# %%
print("POSITION:\n{}".format(drs.get_position()))
print("FORCE:\n{}".format(drs.get_force()))
print("ENERGY:\n{}".format(drs.get_energy()))
# Out:
# POSITION:
# [[ -3.31   68.995  -8.666]
#  [ -3.312  70.017  -8.482]
#  [ -2.981  68.491  -7.793]
#  ...
#  [ 13.045  59.649 -10.135]
#  [ 13.46   60.383 -11.728]
#  [ 17.823  59.643 -10.545]]
# FORCE:
# [[-170.13881836  170.54705182 -381.84728117]
#  [ -39.46084354  -57.46509326   -1.28318654]
#  [ 163.6735801  -275.04277799  586.6397355 ]
#  ...
#  [  45.20746714   -1.60862322  -10.01255564]
#  [ -48.24416473   13.17345614   17.28681141]
#  [-156.06352292  338.86667876  317.24112723]]
# ENERGY:
# -9735.621086658488

# %%
t = np.array([1.0, -2., 0.])
r = rotation_matrix(0, 0, 90)
nmw.set_rigid(t, r)
# pdy.showProtein(drs._ligand, A='green')
nmw.set_rigid(np.array([0, 0,  0]), rotation_matrix(0, 0, 90))
init_pos = drs.get_init_position()
curr_pos = drs.get_position()
pdy.showProtein(drs._ligand_init, A='blue', linewidth=1)
pdy.showProtein(drs._ligand, A='red', width=1)
pylab.show()
# for i in range(len(init_pos)):
#     print("offset:", curr_pos[i] - init_pos[i])
